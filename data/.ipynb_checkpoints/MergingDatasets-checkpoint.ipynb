# %%
import pandas as pd
import re
import numpy as np

# %%
#activity = pd.read_csv('pos_state_collar_2_2018_08_16_precise.csv')
collarC3 = pd.read_csv('9dof_processed_C3.csv')
braceletC3 = pd.read_csv('ble_processed_C3.csv')
gpsC3 = pd.read_csv('gps_processed_C3.csv')
gpsC3['TIME']=gpsC3['TIMESTAMP']
del gpsC3['TIMESTAMP']
collarC3.columns=['TIME', 'collar_ACC_X', 'collar_ACC_Y', 'collar_ACC_Z', 'collar_GYRO_X', 'collar_GYRO_Y', 'collar_GYRO_Z',
       'collar_MAG_X', 'collar_MAG_Y', 'collar_MAG_Z']
braceletC3.columns=['TIME', 'bracelet_ACC_X', 'bracelet_ACC_Y', 'bracelet_ACC_Z', 'bracelet_GYRO_X', 'bracelet_GYRO_Y', 'bracelet_GYRO_Z']

# %%
collarC2 = pd.read_csv('9dof_processed_C2.csv')
braceletC2 = pd.read_csv('ble_processed_C2.csv')
gpsC2 = pd.read_csv('gps_processed_C2.csv')
gpsC2['TIME']=gpsC2['TIMESTAMP']
del gpsC2['TIMESTAMP']
collarC2.columns=['TIME', 'collar_ACC_X', 'collar_ACC_Y', 'collar_ACC_Z', 'collar_GYRO_X', 'collar_GYRO_Y', 'collar_GYRO_Z',
       'collar_MAG_X', 'collar_MAG_Y', 'collar_MAG_Z']
braceletC2.columns=['TIME', 'bracelet_ACC_X', 'bracelet_ACC_Y', 'bracelet_ACC_Z', 'bracelet_GYRO_X', 'bracelet_GYRO_Y', 'bracelet_GYRO_Z']

# %%
min_time=min(collarC2['TIME'])
if min_time > min(braceletC2['TIME']):
    min_time=min(braceletC2['TIME'])
if min_time > min(gpsC2['TIME']):
    min_time=min(gpsC2['TIME'])
if min_time > min(collarC3['TIME']):
    min_time=min(collarC3['TIME'])
if min_time > min(braceletC3['TIME']):
    min_time=min(braceletC3['TIME'])
if min_time > min(gpsC3['TIME']):
    min_time=min(gpsC3['TIME'])

# %%
max_time=max(collarC2['TIME'])
if max_time < max(braceletC2['TIME']):
    max_time=max(braceletC2['TIME'])
if max_time < max(gpsC2['TIME']):
    max_time=max(gpsC2['TIME'])
if max_time < max(collarC3['TIME']):
    max_time=max(collarC3['TIME'])
if max_time < max(braceletC3['TIME']):
    max_time=max(braceletC3['TIME'])
if max_time < max(gpsC3['TIME']):
    max_time=max(gpsC3['TIME'])

# %%
time_list=[]
for i in range(min_time,max_time+1):
    time_list.append(i)
time_list=pd.DataFrame(time_list)
time_list.columns=['TIME']

# %%
collarC3=collarC3.groupby(['TIME'],group_keys=time_list)[ 'collar_ACC_X', 'collar_ACC_Y', 'collar_ACC_Z', 'collar_GYRO_X', 'collar_GYRO_Y', 'collar_GYRO_Z',
       'collar_MAG_X', 'collar_MAG_Y', 'collar_MAG_Z'].mean()
braceletC3=braceletC3.groupby(['TIME'],group_keys=time_list)['bracelet_ACC_X', 'bracelet_ACC_Y', 'bracelet_ACC_Z', 'bracelet_GYRO_X', 'bracelet_GYRO_Y', 'bracelet_GYRO_Z'].mean()
gpsC3=gpsC3.groupby(['TIME']).mean()

# %%
collarC2=collarC2.groupby(['TIME'],group_keys=time_list)[ 'collar_ACC_X', 'collar_ACC_Y', 'collar_ACC_Z', 'collar_GYRO_X', 'collar_GYRO_Y', 'collar_GYRO_Z',
       'collar_MAG_X', 'collar_MAG_Y', 'collar_MAG_Z'].mean()
braceletC2=braceletC2.groupby(['TIME'],group_keys=time_list)['bracelet_ACC_X', 'bracelet_ACC_Y', 'bracelet_ACC_Z', 'bracelet_GYRO_X', 'bracelet_GYRO_Y', 'bracelet_GYRO_Z'].mean()
gpsC2=gpsC2.groupby(['TIME'],group_keys=time_list).mean()

# %%
mergedc3=pd.merge(gpsC3,pd.merge(braceletC3,collarC3,how='outer',on="TIME"),how='outer',on="TIME")
mergedc2=pd.merge(gpsC2,pd.merge(braceletC2,collarC2,how='outer',on="TIME"),how='outer',on="TIME")

# %%
mergedc3=pd.merge(time_list,mergedc3,how='outer',on="TIME")
mergedc2=pd.merge(time_list,mergedc2,how='outer',on="TIME")

# %%
# mergedc3.to_csv('mergedc3.csv')
# mergedc2.to_csv('mergedc2.csv')

# %%
actc3=pd.read_csv('activityc3.csv')
actc2=pd.read_csv('activityc2.csv')
actc3=actc3.dropna()
actc2=actc2.dropna()
actc3['start'] = actc3['start_time'].apply(lambda x: '{:.0f}'.format(x/1000))
actc3['end'] = actc3['end_time'].apply(lambda x: '{:.0f}'.format(x/1000))
actc2['start'] = actc2['start_time'].apply(lambda x: '{:.0f}'.format(x/1000))
actc2['end'] = actc2['end_time'].apply(lambda x: '{:.0f}'.format(x/1000))
del actc2['end_time']
del actc3['end_time']
del actc2['start_time']
del actc3['start_time']

# %%
timestamps=[]
activity=[]
for row in range(len(actc2)):
    #print(actc2['start'][row])
    for i in range(int(actc2['start'][row]),int(actc2['end'][row])):
        #print (i)
        timestamps.append(i)
        activity.append(actc2['Behavior'][row])
activity

activityc2 = pd.DataFrame(
    {'TIME': timestamps,
     'activity': activity   
    })

# %%
timestamps=[]
activity=[]
for row in range(len(actc3)):
    #print(actc2['start'][row])
    for i in range(int(actc3['start'][row]),int(actc3['end'][row])):
        #print (i)
        timestamps.append(i)
        activity.append(actc3['Behavior'][row])
activity

activityc3 = pd.DataFrame(
    {'TIME': timestamps,
     'activity': activity   
    })

# %%
mergedc3=pd.merge(mergedc3,activityc3,how='left',on="TIME")
mergedc2=pd.merge(mergedc2,activityc2,how='left',on="TIME")
mergedc2['activity']=mergedc2['activity'].fillna("Unknown")
mergedc3['activity']=mergedc3['activity'].fillna("Unknown")

# %%
mergedc3.to_csv('mergedc3.csv')
mergedc2.to_csv('mergedc2.csv')

# %%
c=0 
while (pd.isnull(mergedc2.loc[c, 'Latitude'])):
    c = c+1
mergedc2.loc[0,'Latitude'] = mergedc2.loc[c, 'Latitude']

for index in range(mergedc2.shape[0]):
    Lat = mergedc2.loc[index, 'Latitude']
    if (pd.isnull(Lat)):
        mergedc2.loc[index, 'Latitude'] = mergedc2.loc[index-1, 'Latitude'] if pd.isnull(mergedc2.loc[index+1, 'Latitude']) else (mergedc2.loc[index+1, 'Latitude']+mergedc2.loc[index-1, 'Latitude'])/2
        
mergedc2.head(10)
# Out:
#          TIME  Latitude  Longitude  bracelet_ACC_X  bracelet_ACC_Y  \
# 0  1534395958  0.295173        NaN        1.564667       -0.874939
# 1  1534395959  0.295173        NaN        1.563751       -0.872742
# 2  1534395960  0.295173  36.905232        1.564880       -0.873993
# 3  1534395961  0.295173        NaN             NaN             NaN
# 4  1534395962  0.295173        NaN        1.563110       -0.874878
# 5  1534395963  0.295173        NaN        1.562622       -0.874603
# 6  1534395964  0.295180        NaN        1.565094       -0.873047
# 7  1534395965  0.295187  36.905240        1.563446       -0.871338
# 8  1534395966  0.295189  36.905244        1.565216       -0.873627
# 9  1534395967  0.295192        NaN             NaN             NaN
#
#    bracelet_ACC_Z  bracelet_GYRO_X  bracelet_GYRO_Y  bracelet_GYRO_Z  \
# 0       -0.752380         3.149809        -6.442748        -1.513359
# 1       -0.752930         3.154580        -6.399809        -1.637405
# 2       -0.754456         3.050573        -6.368321        -1.669847
# 3             NaN              NaN              NaN              NaN
# 4       -0.753693         3.122137        -6.382634        -1.567748
# 5       -0.753723         3.092557        -6.337786        -1.563931
# 6       -0.748840         3.127863        -6.389313        -1.619275
# 7       -0.750488         3.108779        -6.470420        -1.541985
# 8       -0.752808         3.076336        -6.422710        -1.572519
# 9             NaN              NaN              NaN              NaN
#
#    collar_ACC_X  collar_ACC_Y  collar_ACC_Z  collar_GYRO_X  collar_GYRO_Y  \
# 0      8.772487     -3.886742     -2.391227      -0.000125       0.000693
# 1      8.806784     -3.888736     -2.390430       0.000477       0.002693
# 2      8.827123     -3.823731     -2.372085       0.002238      -0.001034
# 3           NaN           NaN           NaN            NaN            NaN
# 4      8.620143     -4.061816     -2.719842       0.003500       0.003386
# 5      9.150154     -2.336990     -2.086143      -0.004170       0.040713
# 6      9.798210     -1.462812     -0.410369       0.070472       0.011806
# 7     10.395219     -0.866601     -0.088535       0.046769      -0.066836
# 8     10.471790     -0.203789     -0.353340       0.084403       0.057007
# 9           NaN           NaN           NaN            NaN            NaN
#
#    collar_GYRO_Z  collar_MAG_X  collar_MAG_Y  collar_MAG_Z activity
# 0       0.000170    -12.425000    -18.991667    -62.341667  Unknown
# 1       0.001170    -10.950000    -14.783334    -63.191667  Unknown
# 2       0.000636     -9.066667    -13.283334    -65.825003  Unknown
# 3            NaN           NaN           NaN           NaN  Unknown
# 4      -0.002273    -11.858333    -16.875000    -62.933334  Unknown
# 5      -0.029805    -11.908334    -20.933334    -89.025001  Unknown
# 6      -0.031532     -5.983333    -46.841667    -62.275002  Unknown
# 7       0.009715     -3.916667    -43.533334    -51.858334  Unknown
# 8      -0.020362     -1.550000    -29.725000    -43.508334  Unknown
# 9            NaN           NaN           NaN           NaN  Unknown

# %%
# Out:
#          TIME  Latitude  Longitude  bracelet_ACC_X  bracelet_ACC_Y  \
# 0  1534395958  0.295173  36.905232        1.564667       -0.874939
# 1  1534395959  0.295173  36.905232        1.563751       -0.872742
# 2  1534395960  0.295173  36.905232        1.564880       -0.873993
# 3  1534395961  0.295173  36.905232             NaN             NaN
# 4  1534395962  0.295173  36.905232        1.563110       -0.874878
# 5  1534395963  0.295173  36.905232        1.562622       -0.874603
# 6  1534395964  0.295180  36.905236        1.565094       -0.873047
# 7  1534395965  0.295187  36.905240        1.563446       -0.871338
# 8  1534395966  0.295189  36.905244        1.565216       -0.873627
# 9  1534395967  0.295192  36.905246             NaN             NaN
#
#    bracelet_ACC_Z  bracelet_GYRO_X  bracelet_GYRO_Y  bracelet_GYRO_Z  \
# 0       -0.752380         3.149809        -6.442748        -1.513359
# 1       -0.752930         3.154580        -6.399809        -1.637405
# 2       -0.754456         3.050573        -6.368321        -1.669847
# 3             NaN              NaN              NaN              NaN
# 4       -0.753693         3.122137        -6.382634        -1.567748
# 5       -0.753723         3.092557        -6.337786        -1.563931
# 6       -0.748840         3.127863        -6.389313        -1.619275
# 7       -0.750488         3.108779        -6.470420        -1.541985
# 8       -0.752808         3.076336        -6.422710        -1.572519
# 9             NaN              NaN              NaN              NaN
#
#    collar_ACC_X  collar_ACC_Y  collar_ACC_Z  collar_GYRO_X  collar_GYRO_Y  \
# 0      8.772487     -3.886742     -2.391227      -0.000125       0.000693
# 1      8.806784     -3.888736     -2.390430       0.000477       0.002693
# 2      8.827123     -3.823731     -2.372085       0.002238      -0.001034
# 3           NaN           NaN           NaN            NaN            NaN
# 4      8.620143     -4.061816     -2.719842       0.003500       0.003386
# 5      9.150154     -2.336990     -2.086143      -0.004170       0.040713
# 6      9.798210     -1.462812     -0.410369       0.070472       0.011806
# 7     10.395219     -0.866601     -0.088535       0.046769      -0.066836
# 8     10.471790     -0.203789     -0.353340       0.084403       0.057007
# 9           NaN           NaN           NaN            NaN            NaN
#
#    collar_GYRO_Z  collar_MAG_X  collar_MAG_Y  collar_MAG_Z activity
# 0       0.000170    -12.425000    -18.991667    -62.341667  Unknown
# 1       0.001170    -10.950000    -14.783334    -63.191667  Unknown
# 2       0.000636     -9.066667    -13.283334    -65.825003  Unknown
# 3            NaN           NaN           NaN           NaN  Unknown
# 4      -0.002273    -11.858333    -16.875000    -62.933334  Unknown
# 5      -0.029805    -11.908334    -20.933334    -89.025001  Unknown
# 6      -0.031532     -5.983333    -46.841667    -62.275002  Unknown
# 7       0.009715     -3.916667    -43.533334    -51.858334  Unknown
# 8      -0.020362     -1.550000    -29.725000    -43.508334  Unknown
# 9            NaN           NaN           NaN           NaN  Unknown

# %%
for column in mergedc2:
    c=0 
    while (pd.isnull(mergedc2.loc[c, column])):
        c = c+1
    mergedc2.loc[0, column] = mergedc2.loc[c, column]

    for index in range(mergedc2.shape[0]-1):
        Lat = mergedc2.loc[index, column]
        if (pd.isnull(Lat)):
            mergedc2.loc[index, column] = mergedc2.loc[index-1, column] if pd.isnull(mergedc2.loc[index+1, column]) else (mergedc2.loc[index+1, column]+mergedc2.loc[index-1, column])/2

mergedc2.head(10)
# Out:
#          TIME  Latitude  Longitude  bracelet_ACC_X  bracelet_ACC_Y  \
# 0  1534395958  0.295173  36.905232        1.564667       -0.874939
# 1  1534395959  0.295173  36.905232        1.563751       -0.872742
# 2  1534395960  0.295173  36.905232        1.564880       -0.873993
# 3  1534395961  0.295173  36.905232        1.563995       -0.874435
# 4  1534395962  0.295173  36.905232        1.563110       -0.874878
# 5  1534395963  0.295173  36.905232        1.562622       -0.874603
# 6  1534395964  0.295180  36.905236        1.565094       -0.873047
# 7  1534395965  0.295187  36.905240        1.563446       -0.871338
# 8  1534395966  0.295189  36.905244        1.565216       -0.873627
# 9  1534395967  0.295192  36.905246        1.563293       -0.874588
#
#    bracelet_ACC_Z  bracelet_GYRO_X  bracelet_GYRO_Y  bracelet_GYRO_Z  \
# 0       -0.752380         3.149809        -6.442748        -1.513359
# 1       -0.752930         3.154580        -6.399809        -1.637405
# 2       -0.754456         3.050573        -6.368321        -1.669847
# 3       -0.754074         3.086355        -6.375477        -1.618798
# 4       -0.753693         3.122137        -6.382634        -1.567748
# 5       -0.753723         3.092557        -6.337786        -1.563931
# 6       -0.748840         3.127863        -6.389313        -1.619275
# 7       -0.750488         3.108779        -6.470420        -1.541985
# 8       -0.752808         3.076336        -6.422710        -1.572519
# 9       -0.753082         3.093989        -6.391698        -1.602576
#
#    collar_ACC_X  collar_ACC_Y  collar_ACC_Z  collar_GYRO_X  collar_GYRO_Y  \
# 0      8.772487     -3.886742     -2.391227      -0.000125       0.000693
# 1      8.806784     -3.888736     -2.390430       0.000477       0.002693
# 2      8.827123     -3.823731     -2.372085       0.002238      -0.001034
# 3      8.723633     -3.942774     -2.545963       0.002869       0.001176
# 4      8.620143     -4.061816     -2.719842       0.003500       0.003386
# 5      9.150154     -2.336990     -2.086143      -0.004170       0.040713
# 6      9.798210     -1.462812     -0.410369       0.070472       0.011806
# 7     10.395219     -0.866601     -0.088535       0.046769      -0.066836
# 8     10.471790     -0.203789     -0.353340       0.084403       0.057007
# 9     10.201401     -0.165304      0.227518       0.039060       0.032793
#
#    collar_GYRO_Z  collar_MAG_X  collar_MAG_Y  collar_MAG_Z activity
# 0       0.000170    -12.425000    -18.991667    -62.341667  Unknown
# 1       0.001170    -10.950000    -14.783334    -63.191667  Unknown
# 2       0.000636     -9.066667    -13.283334    -65.825003  Unknown
# 3      -0.000818    -10.462500    -15.079167    -64.379169  Unknown
# 4      -0.002273    -11.858333    -16.875000    -62.933334  Unknown
# 5      -0.029805    -11.908334    -20.933334    -89.025001  Unknown
# 6      -0.031532     -5.983333    -46.841667    -62.275002  Unknown
# 7       0.009715     -3.916667    -43.533334    -51.858334  Unknown
# 8      -0.020362     -1.550000    -29.725000    -43.508334  Unknown
# 9      -0.011380     -2.712500    -24.470834    -41.170834  Unknown

# %%
for column in mergedc3:
    c=0 
    while (pd.isnull(mergedc3.loc[c, column])):
        c = c+1
    mergedc3.loc[0, column] = mergedc3.loc[c, column]

    for index in range(mergedc3.shape[0]-1):
        Lat = mergedc3.loc[index, column]
        if (pd.isnull(Lat)):
            mergedc3.loc[index, column] = mergedc3.loc[index-1, column] if pd.isnull(mergedc3.loc[index+1, column]) else (mergedc3.loc[index+1, column]+mergedc3.loc[index-1, column])/2

mergedc3.head(10)
# Out:
#          TIME  Latitude  Longitude  bracelet_ACC_X  bracelet_ACC_Y  \
# 0  1534395958  0.290317  36.896422        0.992798        0.211639
# 1  1534395959  0.290317  36.896422        0.992798        0.211639
# 2  1534395960  0.290317  36.896422        0.992798        0.211639
# 3  1534395961  0.290317  36.896422        0.992798        0.211639
# 4  1534395962  0.290317  36.896422        0.992798        0.211639
# 5  1534395963  0.290317  36.896422        0.992798        0.211639
# 6  1534395964  0.290796  36.896954        0.992798        0.211639
# 7  1534395965  0.291275  36.897487        0.992798        0.211639
# 8  1534395966  0.291275  36.897487        0.992798        0.211639
# 9  1534395967  0.291591  36.898051        0.992798        0.211639
#
#    bracelet_ACC_Z  bracelet_GYRO_X  bracelet_GYRO_Y  bracelet_GYRO_Z  \
# 0       -0.077179         0.686069        -0.901718        -1.071565
# 1       -0.077179         0.686069        -0.901718        -1.071565
# 2       -0.077179         0.686069        -0.901718        -1.071565
# 3       -0.077179         0.686069        -0.901718        -1.071565
# 4       -0.077179         0.686069        -0.901718        -1.071565
# 5       -0.077179         0.686069        -0.901718        -1.071565
# 6       -0.077179         0.686069        -0.901718        -1.071565
# 7       -0.077179         0.686069        -0.901718        -1.071565
# 8       -0.077179         0.686069        -0.901718        -1.071565
# 9       -0.077179         0.686069        -0.901718        -1.071565
#
#    collar_ACC_X  collar_ACC_Y  collar_ACC_Z  collar_GYRO_X  collar_GYRO_Y  \
# 0      7.845268     -2.867399     -5.155336       0.067552      -0.001261
# 1      7.845268     -2.867399     -5.155336       0.067552      -0.001261
# 2      7.845268     -2.867399     -5.155336       0.067552      -0.001261
# 3      7.845268     -2.867399     -5.155336       0.067552      -0.001261
# 4      7.845268     -2.867399     -5.155336       0.067552      -0.001261
# 5      7.845268     -2.867399     -5.155336       0.067552      -0.001261
# 6      7.845268     -2.867399     -5.155336       0.067552      -0.001261
# 7      7.845268     -2.867399     -5.155336       0.067552      -0.001261
# 8      7.845268     -2.867399     -5.155336       0.067552      -0.001261
# 9      7.845268     -2.867399     -5.155336       0.067552      -0.001261
#
#    collar_GYRO_Z  collar_MAG_X  collar_MAG_Y  collar_MAG_Z activity
# 0      -0.027578    -72.133335    -82.058334     70.458334  Unknown
# 1      -0.027578    -72.133335    -82.058334     70.458334  Unknown
# 2      -0.027578    -72.133335    -82.058334     70.458334  Unknown
# 3      -0.027578    -72.133335    -82.058334     70.458334  Unknown
# 4      -0.027578    -72.133335    -82.058334     70.458334  Unknown
# 5      -0.027578    -72.133335    -82.058334     70.458334  Unknown
# 6      -0.027578    -72.133335    -82.058334     70.458334  Unknown
# 7      -0.027578    -72.133335    -82.058334     70.458334  Unknown
# 8      -0.027578    -72.133335    -82.058334     70.458334  Unknown
# 9      -0.027578    -72.133335    -82.058334     70.458334  Unknown

# %%
mergedc3.to_csv('mergedc3.csv')
mergedc2.to_csv('mergedc2.csv')
